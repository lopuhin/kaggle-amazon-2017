# %%
import sys
if '..' not in sys.path:
    sys.path.append('..')
import utils
# %matplotlib inline

# %%
utils.plot(
    #'../runs/resnet50/',
    #'../runs/resnet50-aug/',
    #'../runs/resnet50-aug-fold5/',
    #'../../_runs/fold0_kostia_resnet50_finetune/',
    #'../runs/resnet50-finetune-lr-0.00002-dropout/',
    
    #'../runs/resnet50-finetune-lr-0.00002/',
    #'../runs/resnet101-finetune-lr-0.00002/',
    
    #'../runs/sm-resnet34_finetune-bs8/',
    
    #'../../../planet/runs/resnet50-aug/',
    '../../_runs/fold0_kostia_resnet34/',
    '../../_runs/fold0_kostia_resnet50/',
    '../../_runs/fold0_kostia_densenet121/',
    #ymax=3,
    
    #'../runs/vgg11_bn/',
    #'../runs/vgg16_bn/',
    
    #ymax=0.12, ymin=0.08,
    #'valid_f2', ymin=0.88, ymax=0.93,
    #xmax=10000,
)

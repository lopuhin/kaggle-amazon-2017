# %%
import sys
if '..' not in sys.path:
    sys.path.append('..')
import utils
# %matplotlib inline

# %%
utils.plot(
    #'../runs/resnet50/',
    #'../runs/resnet50-aug/',
    #'../runs/resnet50-aug-fold5/',
    #'../runs/resnet50-finetune/',
    #'../runs/resnet50-finetune-lr-0.00002-dropout/',
    
    #'../runs/resnet50-finetune-lr-0.00002/',
    #'../runs/resnet101-finetune-lr-0.00002/',
    
    '../runs/sm-resnet34_finetune-bs8/',
    ymax=3,
    
    #'../runs/vgg11_bn/',
    #'../runs/vgg16_bn/',
    
    #ymax=0.125, ymin=0.08,
    #'valid_f2', ymin=0.91, ymax=0.93,
    #xmax=10000,
)
